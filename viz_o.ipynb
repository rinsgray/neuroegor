# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.colors as colors
import math as m

# %%
e = {"Al": 0.003799,
     "H": 0.0008617,
     "C": 0.0017,
     "O": 0.001891,
     "Zn": 0.052206781,
     "F": 0.00622696}
g = {"Al": 2.0,
     "H": 1.2,
     "C": 1.7,
     "O": 1.52,
     "Zn": 1.739032,
     "F": 0.812496}

# %%
# from google.colab import drive
# drive.mount('/content/gdrive')

# %%
data = pd.read_csv('dataset_2.csv')

# %%
# %%time
for c in range(len(data)):
    xyze = pd.DataFrame(columns=['x', 'y', 'z', 'el'])
    cifd = data.loc[c]['cif'].splitlines()
    k_a = float(cifd[8].split()[1])
    k_b = float(cifd[9].split()[1])
    k_c = float(cifd[10].split()[1])
    for i in cifd[20:]:
        x = float(i.split()[2]) * k_a
        y = float(i.split()[3]) * k_b
        z = float(i.split()[4]) * k_c
        el = i.split()[1]
        xyze.loc[len(xyze)] = [x, y, z, el]
    xl,yl,zl = (min(xyze['z']), min(xyze['x']), min(xyze['y']))
    xh,yh,zh = (max(xyze['z']), max(xyze['x']), max(xyze['y']))
    print('{} cell_x: {:.2f} cell_y: {:.2f} cell_z: {:.2f}'.format(c,xh-xl,yh-yl,zh-zl))
    zl,xl,yl = (min(xyze['z']), min(xyze['x']), min(xyze['y']))
    zh,xh,yh = (max(xyze['z']), max(xyze['x']), max(xyze['y']))
    print(yh,yl)
    xyze['x']-=xl
    xyze['y']-=yl
    xyze['z']-=zl
    cell_size = max((max(xyze['z']), max(xyze['x']), max(xyze['y'])))
    x_lin = np.linspace(0, cell_size, 51)
    y_lin = np.linspace(0, cell_size, 51)
    z_lin = np.linspace(0, cell_size, 51)
    X, Y, Z = np.meshgrid(x_lin, y_lin, z_lin)
    yy = np.array(xyze[['y']]) - cell_size
    yyy = np.array(xyze[['y']]) + cell_size
    xx = np.array(xyze[['x']]) - cell_size
    xxx = np.array(xyze[['x']]) + cell_size
    zz = np.array(xyze[['z']]) - cell_size
    zzz = np.array(xyze[['z']]) + cell_size
    ellll = xyze[['x', 'y', 'z', 'el']]
    for i in range(len(ellll)):
        ellll.at[i, 'y'] = yyy[i][0]
    p = xyze.append(ellll, ignore_index=True)
    ellll = xyze[['x', 'y', 'z', 'el']]
    for i in range(len(ellll)):
        ellll.at[i, 'y'] = yy[i][0]
    p = p.append(ellll, ignore_index=True)
    ellll = xyze[['x', 'y', 'z', 'el']]
    for i in range(len(ellll)):
        ellll.at[i, 'x'] = xxx[i][0]
    p = p.append(ellll, ignore_index=True)
    ellll = xyze[['x', 'y', 'z', 'el']]
    for i in range(len(ellll)):
        ellll.at[i, 'x'] = xx[i][0]
    p = p.append(ellll, ignore_index=True)
    ellll = xyze[['x', 'y', 'z', 'el']]
    for i in range(len(ellll)):
        ellll.at[i, 'z'] = zz[i][0]
    p = p.append(ellll, ignore_index=True)
    ellll = xyze[['x', 'y', 'z', 'el']]
    for i in range(len(ellll)):
        ellll.at[i, 'z'] = zzz[i][0]
    p = p.append(ellll, ignore_index=True)
    
    xv = np.array(xyze[['x']]) + cell_size
    yv = np.array(xyze[['y']]) + cell_size
    elm = xyze[['x', 'y', 'z', 'el']]
    for i in range(len(elm)):
        elm.at[i, 'x'] = xv[i][0]
        elm.at[i, 'y'] = yv[i][0]
    p = p.append(elm, ignore_index=True)
    
    xv = np.array(xyze[['x']]) - cell_size
    yv = np.array(xyze[['y']]) - cell_size
    elm = xyze[['x', 'y', 'z', 'el']]
    for i in range(len(elm)):
        elm.at[i, 'x'] = xv[i][0]
        elm.at[i, 'y'] = yv[i][0]
    p = p.append(elm, ignore_index=True)
    
    xv = np.array(xyze[['x']]) - cell_size
    yv = np.array(xyze[['y']]) + cell_size
    elm = xyze[['x', 'y', 'z', 'el']]
    for i in range(len(elm)):
        elm.at[i, 'x'] = xv[i][0]
        elm.at[i, 'y'] = yv[i][0]
    p = p.append(elm, ignore_index=True)
    
    xv = np.array(xyze[['x']]) + cell_size
    yv = np.array(xyze[['y']]) - cell_size
    elm = xyze[['x', 'y', 'z', 'el']]
    for i in range(len(elm)):
        elm.at[i, 'x'] = xv[i][0]
        elm.at[i, 'y'] = yv[i][0]
    p = p.append(elm, ignore_index=True)
    
    xv = np.array(xyze[['x']]) + cell_size
    yv = np.array(xyze[['y']]) + cell_size
    zv = np.array(xyze[['z']]) + cell_size
    elm = xyze[['x', 'y', 'z', 'el']]
    for i in range(len(elm)):
        elm.at[i, 'x'] = xv[i][0]
        elm.at[i, 'y'] = yv[i][0]
        elm.at[i, 'z'] = zv[i][0]
    p = p.append(elm, ignore_index=True)
    
    xv = np.array(xyze[['x']]) + cell_size
    yv = np.array(xyze[['y']]) + cell_size
    zv = np.array(xyze[['z']]) - cell_size
    elm = xyze[['x', 'y', 'z', 'el']]
    for i in range(len(elm)):
        elm.at[i, 'x'] = xv[i][0]
        elm.at[i, 'y'] = yv[i][0]
        elm.at[i, 'z'] = zv[i][0]
    p = p.append(elm, ignore_index=True)
    
    xv = np.array(xyze[['x']]) + cell_size
    yv = np.array(xyze[['y']]) - cell_size
    zv = np.array(xyze[['z']]) + cell_size
    elm = xyze[['x', 'y', 'z', 'el']]
    for i in range(len(elm)):
        elm.at[i, 'x'] = xv[i][0]
        elm.at[i, 'y'] = yv[i][0]
        elm.at[i, 'z'] = zv[i][0]
    p = p.append(elm, ignore_index=True)
    
    xv = np.array(xyze[['x']]) - cell_size
    yv = np.array(xyze[['y']]) + cell_size
    zv = np.array(xyze[['z']]) + cell_size
    elm = xyze[['x', 'y', 'z', 'el']]
    for i in range(len(elm)):
        elm.at[i, 'x'] = xv[i][0]
        elm.at[i, 'y'] = yv[i][0]
        elm.at[i, 'z'] = zv[i][0]
    p = p.append(elm, ignore_index=True)

    xv = np.array(xyze[['x']]) - cell_size
    yv = np.array(xyze[['y']]) + cell_size
    zv = np.array(xyze[['z']]) - cell_size
    elm = xyze[['x', 'y', 'z', 'el']]
    for i in range(len(elm)):
        elm.at[i, 'x'] = xv[i][0]
        elm.at[i, 'y'] = yv[i][0]
        elm.at[i, 'z'] = zv[i][0]
    p = p.append(elm, ignore_index=True)

    xv = np.array(xyze[['x']]) - cell_size
    yv = np.array(xyze[['y']]) - cell_size
    zv = np.array(xyze[['z']]) + cell_size
    elm = xyze[['x', 'y', 'z', 'el']]
    for i in range(len(elm)):
        elm.at[i, 'x'] = xv[i][0]
        elm.at[i, 'y'] = yv[i][0]
        elm.at[i, 'z'] = zv[i][0]
    p = p.append(elm, ignore_index=True)
    
    xv = np.array(xyze[['x']]) - cell_size
    yv = np.array(xyze[['y']]) - cell_size
    zv = np.array(xyze[['z']]) - cell_size
    elm = xyze[['x', 'y', 'z', 'el']]
    for i in range(len(elm)):
        elm.at[i, 'x'] = xv[i][0]
        elm.at[i, 'y'] = yv[i][0]
        elm.at[i, 'z'] = zv[i][0]
    p = p.append(elm, ignore_index=True)
    
    xv = np.array(xyze[['x']]) + cell_size
    zv = np.array(xyze[['z']]) + cell_size
    elm = xyze[['x', 'y', 'z', 'el']]
    for i in range(len(elm)):
        elm.at[i, 'x'] = xv[i][0]
        elm.at[i, 'z'] = zv[i][0]
    p = p.append(elm, ignore_index=True)
    xv = np.array(xyze[['x']]) + cell_size
    zv = np.array(xyze[['z']]) - cell_size
    elm = xyze[['x', 'y', 'z', 'el']]
    for i in range(len(elm)):
        elm.at[i, 'x'] = xv[i][0]
        elm.at[i, 'z'] = zv[i][0]
    p = p.append(elm, ignore_index=True)
    xv = np.array(xyze[['x']]) - cell_size
    zv = np.array(xyze[['z']]) + cell_size
    elm = xyze[['x', 'y', 'z', 'el']]
    for i in range(len(elm)):
        elm.at[i, 'x'] = xv[i][0]
        elm.at[i, 'z'] = zv[i][0]
    p = p.append(elm, ignore_index=True)
    xv = np.array(xyze[['x']]) - cell_size
    zv = np.array(xyze[['z']]) - cell_size
    elm = xyze[['x', 'y', 'z', 'el']]
    for i in range(len(elm)):
        elm.at[i, 'x'] = xv[i][0]
        elm.at[i, 'z'] = zv[i][0]
    p = p.append(elm, ignore_index=True)
    
    yv = np.array(xyze[['y']]) + cell_size
    zv = np.array(xyze[['z']]) + cell_size
    elm = xyze[['x', 'y', 'z', 'el']]
    for i in range(len(elm)):
        elm.at[i, 'y'] = yv[i][0]
        elm.at[i, 'z'] = zv[i][0]
    p = p.append(elm, ignore_index=True)
    yv = np.array(xyze[['y']]) + cell_size
    zv = np.array(xyze[['z']]) - cell_size
    elm = xyze[['x', 'y', 'z', 'el']]
    for i in range(len(elm)):
        elm.at[i, 'y'] = yv[i][0]
        elm.at[i, 'z'] = zv[i][0]
    p = p.append(elm, ignore_index=True)
    yv = np.array(xyze[['y']]) - cell_size
    zv = np.array(xyze[['z']]) + cell_size
    elm = xyze[['x', 'y', 'z', 'el']]
    for i in range(len(elm)):
        elm.at[i, 'y'] = yv[i][0]
        elm.at[i, 'z'] = zv[i][0]
    p = p.append(elm, ignore_index=True)
    yv = np.array(xyze[['y']]) - cell_size
    zv = np.array(xyze[['z']]) - cell_size
    elm = xyze[['x', 'y', 'z', 'el']]
    for i in range(len(elm)):
        elm.at[i, 'y'] = yv[i][0]
        elm.at[i, 'z'] = zv[i][0]
    p = p.append(elm, ignore_index=True)
    print(len(p)) 
    p.drop(p[(p['x']<-4) | (p['x']>cell_size+4)|(p['y']<-4) | (p['y']>cell_size+4)|(p['z']<-4) | (p['z']>cell_size+4)].index,inplace = True)
    e_l = []
    g_l = []
    for i in np.array(p[['el']]):
      e_l.append(e[i[0]])
      g_l.append(g[i[0]])
    p['e'] = e_l
    p['g'] = g_l
    p = p.drop(['el'], axis=1)
    print(len(p)) 

    def JL(e, g, r):
        if r == 0:
            r = 0.1
        return 4*e*((g/r)**12 - (g/r)**6)


    @np.vectorize
    def ff(x, y, z):
        en = 0
        for obj in np.array(p[['x', 'y', 'z', 'e', 'g']]):
            r1 = ((x - float(obj[0]))**2 + (y - float(obj[1]))**2 +
                  (z - float(obj[2]))**2)**0.5
            en += JL(float(obj[3]), float(obj[4]), r1)
        return en
    
    
    ee = ff(X, Y, Z)
    break
# Out:
# 0 cell_x: 12.80 cell_y: 12.63 cell_z: 12.80
# -11.555130455417 -24.360031479383
# 1378
# 129
# Wall time: 33.3 s

# %%
ee
# Out:
# array([[[-3.48639978e-05, -3.46667761e-05, -3.46958742e-05, ...,
#          -4.97886551e-05, -4.55840100e-05, -4.17294984e-05],
#         [-3.82426017e-05, -3.79363119e-05, -3.78788222e-05, ...,
#          -5.42298901e-05, -4.96358286e-05, -4.54083099e-05],
#         [-4.21949274e-05, -4.17262962e-05, -4.15389519e-05, ...,
#          -5.94508870e-05, -5.43683732e-05, -4.96818995e-05],
#         ...,
#         [-9.44117407e-05, -9.48000338e-05, -9.60462719e-05, ...,
#          -1.41171308e-04, -1.27316485e-04, -1.15050983e-04],
#         [-8.47641475e-05, -8.53234845e-05, -8.66156781e-05, ...,
#          -1.25762627e-04, -1.13787242e-04, -1.03098241e-04],
#         [-7.61289977e-05, -7.68079049e-05, -7.81143116e-05, ...,
#          -1.12225723e-04, -1.01824902e-04, -9.24780979e-05]],
#
#        [[-3.74906474e-05, -3.72743221e-05, -3.73093086e-05, ...,
#          -5.47078904e-05, -4.99292734e-05, -4.55740170e-05],
#         [-4.12141167e-05, -4.08569208e-05, -4.07801004e-05, ...,
#          -5.96579546e-05, -5.44190660e-05, -4.96280571e-05],
#         [-4.56002236e-05, -4.50410159e-05, -4.48022174e-05, ...,
#          -6.54934633e-05, -5.96847754e-05, -5.43623271e-05],
#         ...,
#         [-1.05602797e-04, -1.05909225e-04, -1.07197441e-04, ...,
#          -1.56019870e-04, -1.40783763e-04, -1.27303688e-04],
#         [-9.43308474e-05, -9.48334834e-05, -9.61758781e-05, ...,
#          -1.38812771e-04, -1.25574634e-04, -1.13777223e-04],
#         [-8.43228727e-05, -8.49666177e-05, -8.63298008e-05, ...,
#          -1.23722946e-04, -1.12172157e-04, -1.01817120e-04]],
#
#        [[-4.02551917e-05, -4.00210174e-05, -4.00651028e-05, ...,
#          -6.01405881e-05, -5.46963729e-05, -4.97669947e-05],
#         [-4.43349977e-05, -4.39243138e-05, -4.38287770e-05, ...,
#          -6.56346774e-05, -5.96492216e-05, -5.42132545e-05],
#         [-4.91801137e-05, -4.85230376e-05, -4.82299206e-05, ...,
#          -7.21342411e-05, -6.54868967e-05, -5.94381506e-05],
#         ...,
#         [-1.18205033e-04, -1.18392279e-04, -1.19701212e-04, ...,
#          -1.72826760e-04, -1.56004668e-04, -1.41143060e-04],
#         [-1.05000307e-04, -1.05412131e-04, -1.06784908e-04, ...,
#          -1.53491171e-04, -1.38800990e-04, -1.25740646e-04],
#         [-9.33828797e-05, -9.39615477e-05, -9.53639676e-05, ...,
#          -1.36588472e-04, -1.23713965e-04, -1.12208812e-04]],
#
#        ...,
#
#        [[-3.29018601e-05, -3.25224523e-05, -3.23011825e-05, ...,
#          -4.00854173e-05, -3.73181877e-05, -3.46952282e-05],
#         [-3.58946420e-05, -3.54521642e-05, -3.51819766e-05, ...,
#          -4.38404147e-05, -4.07830213e-05, -3.78743708e-05],
#         [-3.93270170e-05, -3.87821236e-05, -3.84324354e-05, ...,
#          -4.82342429e-05, -4.47999721e-05, -4.15310530e-05],
#         ...,
#         [-7.83308168e-05, -7.80262340e-05, -7.84648020e-05, ...,
#          -1.19682831e-04, -1.07167525e-04, -9.60075579e-05],
#         [-7.14900122e-05, -7.14146484e-05, -7.19669750e-05, ...,
#          -1.06764045e-04, -9.61463338e-05, -8.65794863e-05],
#         [-6.51981685e-05, -6.52952792e-05, -6.59229631e-05, ...,
#          -9.53416626e-05, -8.63010613e-05, -7.80806159e-05]],
#
#        [[-3.33149397e-05, -3.28332983e-05, -3.25135891e-05, ...,
#          -4.00316448e-05, -3.72738326e-05, -3.46569954e-05],
#         [-3.64113258e-05, -3.58382102e-05, -3.54443141e-05, ...,
#          -4.39267619e-05, -4.08511450e-05, -3.79235488e-05],
#         [-3.99893933e-05, -3.92792222e-05, -3.87750896e-05, ...,
#          -4.85185674e-05, -4.50306018e-05, -4.17107255e-05],
#         ...,
#         [-7.73259251e-05, -7.72862415e-05, -7.80187819e-05, ...,
#          -1.18365715e-04, -1.05870623e-04, -9.47521288e-05],
#         [-7.04186800e-05, -7.05882099e-05, -7.14083673e-05, ...,
#          -1.05383628e-04, -9.47961251e-05, -8.52792727e-05],
#         [-6.41027829e-05, -6.44219956e-05, -6.52898434e-05, ...,
#          -9.39319293e-05, -8.49306738e-05, -7.67670450e-05]],
#
#        [[-3.38925025e-05, -3.33039067e-05, -3.28821259e-05, ...,
#          -4.02531099e-05, -3.74781137e-05, -3.48426752e-05],
#         [-3.71144625e-05, -3.64017995e-05, -3.58773574e-05, ...,
#          -4.43259751e-05, -4.11976028e-05, -3.82196741e-05],
#         [-4.08704028e-05, -3.99810461e-05, -3.93116799e-05, ...,
#          -4.91650882e-05, -4.55800513e-05, -4.21702328e-05],
#         ...,
#         [-7.71329945e-05, -7.73144067e-05, -7.83123401e-05, ...,
#          -1.18164075e-04, -1.05550136e-04, -9.43499088e-05],
#         [-7.00302423e-05, -7.04092777e-05, -7.14746761e-05, ...,
#          -1.04959457e-04, -9.42815640e-05, -8.47082679e-05],
#         [-6.35821160e-05, -6.40949638e-05, -6.51851453e-05, ...,
#          -9.33424000e-05, -8.42765963e-05, -7.60781788e-05]]])

# %%
ee_reshaped = ee.reshape(ee.shape[0], -1)
  
# saving reshaped array to file.
np.savetxt("geekfile.txt", ee_reshaped)
  
# retrieving data from file.
loaded_arr = np.loadtxt("geekfile.txt")
  
# This loadedArr is a 2D array, therefore
# we need to convert it to the original
# array shape.reshaping to get original
# matrice with original shape.
load_original_arr = loaded_arr.reshape(
    loaded_arr.shape[0], loaded_arr.shape[1] // 51, 51)
  
# check the shapes:
print("shape of arr: ", ee.shape)
print("shape of load_original_arr: ", load_original_arr.shape)
  
# check if both arrays are same or not:
if (load_original_arr == ee).all():
    print("Yes, both the arrays are same")
else:
    print("No, both the arrays are not same")
# Out:
# shape of arr:  (51, 51, 51)
# shape of load_original_arr:  (51, 51, 51)
# Yes, both the arrays are same

# %%
# %%time
# Out:
# CPU times: user 1min 37s, sys: 672 ms, total: 1min 38s
# Wall time: 1min 38s

# %%
p.iloc[[3]]['x']
# Out:
# 3    6.536216
# Name: x, dtype: float64

# %%
def binary_search(df, target, threshold=4):
  # Get the 'x' column from the DataFrame as a NumPy array
  arr = df['x'].values
  # Set the initial low and high indices for the binary search
  low = 0
  high = len(arr) - 1
  results = pd.DataFrame(columns=['x', 'y', 'z', 'e', 'g'])  # Initialize an empty list to store the results

  # Loop until the low index is greater than the high index
  while low <= high:
    # Calculate the midpoint of the current range
    mid = (low + high) // 2
    # If the difference between the target and the midpoint value is within the threshold, add the corresponding row to the results
    if abs(arr[mid] - target) <= threshold:
      results = results.append(df.iloc[mid])
      # Set the low index to be one greater than the midpoint to search for more values in the upper half of the list
      low = mid + 1
    # If the midpoint value is less than the target, set the low index to be one greater than the midpoint
    elif arr[mid] < target:
      low = mid + 1
    # If the midpoint value is greater than the target, set the high index to be one less than the midpoint
    else:
      high = mid - 1

  # Return the list of results
  return results


@np.vectorize
def ff_sort(x, y, z):
    points = pd.DataFrame(columns=['x', 'y', 'z', 'e', 'g'])
    x_sort = p.sort_values(by='x', ascending=False, kind="heapsort")
    y_sort = p.sort_values(by='y', ascending=False, kind="heapsort")
    z_sort = p.sort_values(by='z', ascending=False, kind="heapsort")
    points = points.append(binary_search(x_sort, x))
    points = points.append(binary_search(y_sort, y))
    points = points.append(binary_search(z_sort, z))
    points = points.drop_duplicates()
    en = 0
    for obj in np.array(points[['x', 'y', 'z', 'e', 'g']]):
        r1 = ((x - float(obj[0]))**2 + (y - float(obj[1]))**2 +
              (z - float(obj[2]))**2)**0.5
        en += JL(float(obj[3]), float(obj[4]), r1)
    return en

# %%
# %%time
eee = ff_sort(X, Y, Z)
# Out:
# /tmp/ipykernel_18184/1289577024.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   points = points.append(binary_search(x_sort, x))
# /tmp/ipykernel_18184/1289577024.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(df.iloc[mid])
# /tmp/ipykernel_18184/1289577024.py:36: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   points = points.append(binary_search(y_sort, y))
# /tmp/ipykernel_18184/1289577024.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(df.iloc[mid])
# /tmp/ipykernel_18184/1289577024.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(df.iloc[mid])
# /tmp/ipykernel_18184/1289577024.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(df.iloc[mid])
# /tmp/ipykernel_18184/1289577024.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(df.iloc[mid])
# /tmp/ipykernel_18184/1289577024.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   points = points.append(binary_search(z_sort, z))
# /tmp/ipykernel_18184/1289577024.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   points = points.append(binary_search(x_sort, x))
# /tmp/ipykernel_18184/1289577024.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(df.iloc[mid])
# /tmp/ipykernel_18184/1289577024.py:36: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   points = points.append(binary_search(y_sort, y))
# /tmp/ipykernel_18184/1289577024.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(df.iloc[mid])
# /tmp/ipykernel_18184/1289577024.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(df.iloc[mid])
# /tmp/ipykernel_18184/1289577024.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(df.iloc[mid])
# /tmp/ipykernel_18184/1289577024.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(df.iloc[mid])
# /tmp/ipykernel_18184/1289577024.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   points = points.append(binary_search(z_sort, z))
# /tmp/ipykernel_18184/1289577024.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   points = points.append(binary_search(x_sort, x))
# /tmp/ipykernel_18184/1289577024.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(df.iloc[mid])
# /tmp/ipykernel_18184/1289577024.py:36: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   points = points.append(binary_search(y_sort, y))
# /tmp/ipykernel_18184/1289577024.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(df.iloc[mid])
# /tmp/ipykernel_18184/1289577024.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(df.iloc[mid])
# /tmp/ipykernel_18184/1289577024.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(df.iloc[mid])
# /tmp/ipykernel_18184/1289577024.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   points = points.append(binary_search(z_sort, z))
# /tmp/ipykernel_18184/1289577024.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   points = points.append(binary_search(x_sort, x))
# /tmp/ipykernel_18184/1289577024.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(df.iloc[mid])
# /tmp/ipykernel_18184/1289577024.py:36: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   points = points.append(binary_search(y_sort, y))
# /tmp/ipykernel_18184/1289577024.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(df.iloc[mid])
# /tmp/ipykernel_18184/1289577024.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   points = points.append(binary_search(z_sort, z))
# /tmp/ipykernel_18184/1289577024.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(df.iloc[mid])
# /tmp/ipykernel_18184/1289577024.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(df.iloc[mid])
# /tmp/ipykernel_18184/1289577024.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   points = points.append(binary_search(x_sort, x))
# /tmp/ipykernel_18184/1289577024.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(df.iloc[mid])
# /tmp/ipykernel_18184/1289577024.py:36: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   points = points.append(binary_search(y_sort, y))
# /tmp/ipykernel_18184/1289577024.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(df.iloc[mid])
# /tmp/ipykernel_18184/1289577024.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(df.iloc[mid])
# /tmp/ipykernel_18184/1289577024.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(df.iloc[mid])
# /tmp/ipykernel_18184/1289577024.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(df.iloc[mid])
# /tmp/ipykernel_18184/1289577024.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   points = points.append(binary_search(z_sort, z))
# /tmp/ipykernel_18184/1289577024.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(df.iloc[mid])
# /tmp/ipykernel_18184/1289577024.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(df.iloc[mid])
# /tmp/ipykernel_18184/1289577024.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   points = points.append(binary_search(x_sort, x))
# /tmp/ipykernel_18184/1289577024.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(df.iloc[mid])
# /tmp/ipykernel_18184/1289577024.py:36: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   points = points.append(binary_search(y_sort, y))
# /tmp/ipykernel_18184/1289577024.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(df.iloc[mid])
# /tmp/ipykernel_18184/1289577024.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(df.iloc[mid])
# /tmp/ipykernel_18184/1289577024.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(df.iloc[mid])
# /tmp/ipykernel_18184/1289577024.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   points = points.append(binary_search(z_sort, z))
# /tmp/ipykernel_18184/1289577024.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(df.iloc[mid])
# /tmp/ipykernel_18184/1289577024.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(df.iloc[mid])
# /tmp/ipykernel_18184/1289577024.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   points = points.append(binary_search(x_sort, x))
# /tmp/ipykernel_18184/1289577024.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(df.iloc[mid])
# /tmp/ipykernel_18184/1289577024.py:36: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   points = points.append(binary_search(y_sort, y))
# /tmp/ipykernel_18184/1289577024.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(df.iloc[mid])
# /tmp/ipykernel_18184/1289577024.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   points = points.append(binary_search(z_sort, z))
# /tmp/ipykernel_18184/1289577024.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   points = points.append(binary_search(x_sort, x))
# /tmp/ipykernel_18184/1289577024.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(df.iloc[mid])
# /tmp/ipykernel_18184/1289577024.py:36: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   points = points.append(binary_search(y_sort, y))
# /tmp/ipykernel_18184/1289577024.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(df.iloc[mid])
# /tmp/ipykernel_18184/1289577024.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(df.iloc[mid])
# /tmp/ipykernel_18184/1289577024.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(df.iloc[mid])
# /tmp/ipykernel_18184/1289577024.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(df.iloc[mid])
# /tmp/ipykernel_18184/1289577024.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   points = points.append(binary_search(z_sort, z))
# /tmp/ipykernel_18184/1289577024.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   points = points.append(binary_search(x_sort, x))
# /tmp/ipykernel_18184/1289577024.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(df.iloc[mid])
# /tmp/ipykernel_18184/1289577024.py:36: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   points = points.append(binary_search(y_sort, y))
# /tmp/ipykernel_18184/1289577024.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(df.iloc[mid])
# /tmp/ipykernel_18184/1289577024.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(df.iloc[mid])
# /tmp/ipykernel_18184/1289577024.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(df.iloc[mid])
# /tmp/ipykernel_18184/1289577024.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   points = points.append(binary_search(z_sort, z))
# /tmp/ipykernel_18184/1289577024.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   points = points.append(binary_search(x_sort, x))
# /tmp/ipykernel_18184/1289577024.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(df.iloc[mid])
# /tmp/ipykernel_18184/1289577024.py:36: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   points = points.append(binary_search(y_sort, y))
# /tmp/ipykernel_18184/1289577024.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(df.iloc[mid])
# /tmp/ipykernel_18184/1289577024.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   points = points.append(binary_search(z_sort, z))
# /tmp/ipykernel_18184/1289577024.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   points = points.append(binary_search(x_sort, x))
# /tmp/ipykernel_18184/1289577024.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(df.iloc[mid])
# /tmp/ipykernel_18184/1289577024.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(df.iloc[mid])
# /tmp/ipykernel_18184/1289577024.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(df.iloc[mid])
# /tmp/ipykernel_18184/1289577024.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(df.iloc[mid])
# /tmp/ipykernel_18184/1289577024.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(df.iloc[mid])
# /tmp/ipykernel_18184/1289577024.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(df.iloc[mid])
# /tmp/ipykernel_18184/1289577024.py:36: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   points = points.append(binary_search(y_sort, y))
# /tmp/ipykernel_18184/1289577024.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(df.iloc[mid])
# /tmp/ipykernel_18184/1289577024.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(df.iloc[mid])
# /tmp/ipykernel_18184/1289577024.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(df.iloc[mid])
# /tmp/ipykernel_18184/1289577024.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(df.iloc[mid])
# /tmp/ipykernel_18184/1289577024.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   points = points.append(binary_search(z_sort, z))
# /tmp/ipykernel_18184/1289577024.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   points = points.append(binary_search(x_sort, x))
# /tmp/ipykernel_18184/1289577024.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(df.iloc[mid])
# /tmp/ipykernel_18184/1289577024.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(df.iloc[mid])
# /tmp/ipykernel_18184/1289577024.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(df.iloc[mid])
# /tmp/ipykernel_18184/1289577024.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(df.iloc[mid])
# /tmp/ipykernel_18184/1289577024.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(df.iloc[mid])
# /tmp/ipykernel_18184/1289577024.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(df.iloc[mid])
# /tmp/ipykernel_18184/1289577024.py:36: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   points = points.append(binary_search(y_sort, y))
# /tmp/ipykernel_18184/1289577024.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(df.iloc[mid])
# /tmp/ipykernel_18184/1289577024.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(df.iloc[mid])
# /tmp/ipykernel_18184/1289577024.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(df.iloc[mid])
# /tmp/ipykernel_18184/1289577024.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   points = points.append(binary_search(z_sort, z))
# /tmp/ipykernel_18184/1289577024.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   points = points.append(binary_search(x_sort, x))
# /tmp/ipykernel_18184/1289577024.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(df.iloc[mid])
# /tmp/ipykernel_18184/1289577024.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(df.iloc[mid])
# /tmp/ipykernel_18184/1289577024.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(df.iloc[mid])
# /tmp/ipykernel_18184/1289577024.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(df.iloc[mid])
# /tmp/ipykernel_18184/1289577024.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(df.iloc[mid])
# /tmp/ipykernel_18184/1289577024.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(df.iloc[mid])
# /tmp/ipykernel_18184/1289577024.py:36: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   points = points.append(binary_search(y_sort, y))
# /tmp/ipykernel_18184/1289577024.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(df.iloc[mid])
# /tmp/ipykernel_18184/1289577024.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   points = points.append(binary_search(z_sort, z))
# /tmp/ipykernel_18184/1289577024.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(df.iloc[mid])
# /tmp/ipykernel_18184/1289577024.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(df.iloc[mid])
# /tmp/ipykernel_18184/1289577024.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   points = points.append(binary_search(x_sort, x))
# /tmp/ipykernel_18184/1289577024.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(df.iloc[mid])
# /tmp/ipykernel_18184/1289577024.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(df.iloc[mid])
# /tmp/ipykernel_18184/1289577024.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(df.iloc[mid])
# /tmp/ipykernel_18184/1289577024.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(df.iloc[mid])
# /tmp/ipykernel_18184/1289577024.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(df.iloc[mid])
# /tmp/ipykernel_18184/1289577024.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(df.iloc[mid])
# /tmp/ipykernel_18184/1289577024.py:36: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   points = points.append(binary_search(y_sort, y))
# /tmp/ipykernel_18184/1289577024.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(df.iloc[mid])
# /tmp/ipykernel_18184/1289577024.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(df.iloc[mid])
# /tmp/ipykernel_18184/1289577024.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(df.iloc[mid])
# /tmp/ipykernel_18184/1289577024.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(df.iloc[mid])
# /tmp/ipykernel_18184/1289577024.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   points = points.append(binary_search(z_sort, z))
# /tmp/ipykernel_18184/1289577024.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(df.iloc[mid])
# /tmp/ipykernel_18184/1289577024.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(df.iloc[mid])
# /tmp/ipykernel_18184/1289577024.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   points = points.append(binary_search(x_sort, x))
# /tmp/ipykernel_18184/1289577024.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(df.iloc[mid])
# /tmp/ipykernel_18184/1289577024.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(df.iloc[mid])
# /tmp/ipykernel_18184/1289577024.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(df.iloc[mid])
# /tmp/ipykernel_18184/1289577024.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(df.iloc[mid])
# /tmp/ipykernel_18184/1289577024.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(df.iloc[mid])
# /tmp/ipykernel_18184/1289577024.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(df.iloc[mid])
# /tmp/ipykernel_18184/1289577024.py:36: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   points = points.append(binary_search(y_sort, y))
# /tmp/ipykernel_18184/1289577024.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(df.iloc[mid])
# /tmp/ipykernel_18184/1289577024.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(df.iloc[mid])
# /tmp/ipykernel_18184/1289577024.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(df.iloc[mid])
# /tmp/ipykernel_18184/1289577024.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   points = points.append(binary_search(z_sort, z))
# /tmp/ipykernel_18184/1289577024.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(df.iloc[mid])
# /tmp/ipykernel_18184/1289577024.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(df.iloc[mid])
# /tmp/ipykernel_18184/1289577024.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   points = points.append(binary_search(x_sort, x))
# /tmp/ipykernel_18184/1289577024.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(df.iloc[mid])
# /tmp/ipykernel_18184/1289577024.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(df.iloc[mid])
# /tmp/ipykernel_18184/1289577024.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(df.iloc[mid])
# /tmp/ipykernel_18184/1289577024.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(df.iloc[mid])
# /tmp/ipykernel_18184/1289577024.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(df.iloc[mid])
# /tmp/ipykernel_18184/1289577024.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(df.iloc[mid])
# /tmp/ipykernel_18184/1289577024.py:36: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   points = points.append(binary_search(y_sort, y))
# /tmp/ipykernel_18184/1289577024.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(df.iloc[mid])
# CPU times: user 422 ms, sys: 2.73 ms, total: 424 ms
# Wall time: 410 ms
# /tmp/ipykernel_18184/1289577024.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   points = points.append(binary_search(z_sort, z))
# /tmp/ipykernel_18184/1289577024.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   points = points.append(binary_search(x_sort, x))
# /tmp/ipykernel_18184/1289577024.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(df.iloc[mid])
# /tmp/ipykernel_18184/1289577024.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(df.iloc[mid])
# /tmp/ipykernel_18184/1289577024.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(df.iloc[mid])
# /tmp/ipykernel_18184/1289577024.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(df.iloc[mid])
# /tmp/ipykernel_18184/1289577024.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(df.iloc[mid])
# /tmp/ipykernel_18184/1289577024.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(df.iloc[mid])
# /tmp/ipykernel_18184/1289577024.py:36: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   points = points.append(binary_search(y_sort, y))
# /tmp/ipykernel_18184/1289577024.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(df.iloc[mid])
# /tmp/ipykernel_18184/1289577024.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(df.iloc[mid])
# /tmp/ipykernel_18184/1289577024.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(df.iloc[mid])
# /tmp/ipykernel_18184/1289577024.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(df.iloc[mid])
# /tmp/ipykernel_18184/1289577024.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   points = points.append(binary_search(z_sort, z))
# /tmp/ipykernel_18184/1289577024.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   points = points.append(binary_search(x_sort, x))
# /tmp/ipykernel_18184/1289577024.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(df.iloc[mid])
# /tmp/ipykernel_18184/1289577024.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(df.iloc[mid])
# /tmp/ipykernel_18184/1289577024.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(df.iloc[mid])
# /tmp/ipykernel_18184/1289577024.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(df.iloc[mid])
# /tmp/ipykernel_18184/1289577024.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(df.iloc[mid])
# /tmp/ipykernel_18184/1289577024.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(df.iloc[mid])
# /tmp/ipykernel_18184/1289577024.py:36: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   points = points.append(binary_search(y_sort, y))
# /tmp/ipykernel_18184/1289577024.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(df.iloc[mid])
# /tmp/ipykernel_18184/1289577024.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(df.iloc[mid])
# /tmp/ipykernel_18184/1289577024.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(df.iloc[mid])
# /tmp/ipykernel_18184/1289577024.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   points = points.append(binary_search(z_sort, z))
# /tmp/ipykernel_18184/1289577024.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   points = points.append(binary_search(x_sort, x))
# /tmp/ipykernel_18184/1289577024.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(df.iloc[mid])
# /tmp/ipykernel_18184/1289577024.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(df.iloc[mid])
# /tmp/ipykernel_18184/1289577024.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(df.iloc[mid])
# /tmp/ipykernel_18184/1289577024.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(df.iloc[mid])
# /tmp/ipykernel_18184/1289577024.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(df.iloc[mid])
# /tmp/ipykernel_18184/1289577024.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(df.iloc[mid])
# /tmp/ipykernel_18184/1289577024.py:36: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   points = points.append(binary_search(y_sort, y))
# /tmp/ipykernel_18184/1289577024.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(df.iloc[mid])
# /tmp/ipykernel_18184/1289577024.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   points = points.append(binary_search(z_sort, z))
# /tmp/ipykernel_18184/1289577024.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   points = points.append(binary_search(x_sort, x))
# /tmp/ipykernel_18184/1289577024.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(df.iloc[mid])
# /tmp/ipykernel_18184/1289577024.py:36: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   points = points.append(binary_search(y_sort, y))
# /tmp/ipykernel_18184/1289577024.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(df.iloc[mid])
# /tmp/ipykernel_18184/1289577024.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(df.iloc[mid])
# /tmp/ipykernel_18184/1289577024.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(df.iloc[mid])
# /tmp/ipykernel_18184/1289577024.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(df.iloc[mid])
# /tmp/ipykernel_18184/1289577024.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   points = points.append(binary_search(z_sort, z))
# /tmp/ipykernel_18184/1289577024.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   points = points.append(binary_search(x_sort, x))
# /tmp/ipykernel_18184/1289577024.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(df.iloc[mid])
# /tmp/ipykernel_18184/1289577024.py:36: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   points = points.append(binary_search(y_sort, y))
# /tmp/ipykernel_18184/1289577024.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(df.iloc[mid])
# /tmp/ipykernel_18184/1289577024.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(df.iloc[mid])
# /tmp/ipykernel_18184/1289577024.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(df.iloc[mid])
# /tmp/ipykernel_18184/1289577024.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   points = points.append(binary_search(z_sort, z))
# /tmp/ipykernel_18184/1289577024.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   points = points.append(binary_search(x_sort, x))
# /tmp/ipykernel_18184/1289577024.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(df.iloc[mid])
# /tmp/ipykernel_18184/1289577024.py:36: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   points = points.append(binary_search(y_sort, y))
# /tmp/ipykernel_18184/1289577024.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(df.iloc[mid])
# /tmp/ipykernel_18184/1289577024.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   points = points.append(binary_search(z_sort, z))
# /tmp/ipykernel_18184/1289577024.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(df.iloc[mid])
# /tmp/ipykernel_18184/1289577024.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(df.iloc[mid])
# /tmp/ipykernel_18184/1289577024.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   points = points.append(binary_search(x_sort, x))
# /tmp/ipykernel_18184/1289577024.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(df.iloc[mid])
# /tmp/ipykernel_18184/1289577024.py:36: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   points = points.append(binary_search(y_sort, y))
# /tmp/ipykernel_18184/1289577024.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(df.iloc[mid])
# /tmp/ipykernel_18184/1289577024.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(df.iloc[mid])
# /tmp/ipykernel_18184/1289577024.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(df.iloc[mid])
# /tmp/ipykernel_18184/1289577024.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(df.iloc[mid])
# /tmp/ipykernel_18184/1289577024.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   points = points.append(binary_search(z_sort, z))
# /tmp/ipykernel_18184/1289577024.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(df.iloc[mid])
# /tmp/ipykernel_18184/1289577024.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(df.iloc[mid])
# /tmp/ipykernel_18184/1289577024.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   points = points.append(binary_search(x_sort, x))
# /tmp/ipykernel_18184/1289577024.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(df.iloc[mid])
# /tmp/ipykernel_18184/1289577024.py:36: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   points = points.append(binary_search(y_sort, y))
# /tmp/ipykernel_18184/1289577024.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(df.iloc[mid])
# /tmp/ipykernel_18184/1289577024.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(df.iloc[mid])
# /tmp/ipykernel_18184/1289577024.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(df.iloc[mid])
# /tmp/ipykernel_18184/1289577024.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   points = points.append(binary_search(z_sort, z))
# /tmp/ipykernel_18184/1289577024.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(df.iloc[mid])
# /tmp/ipykernel_18184/1289577024.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(df.iloc[mid])
# /tmp/ipykernel_18184/1289577024.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   points = points.append(binary_search(x_sort, x))
# /tmp/ipykernel_18184/1289577024.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(df.iloc[mid])
# /tmp/ipykernel_18184/1289577024.py:36: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   points = points.append(binary_search(y_sort, y))
# /tmp/ipykernel_18184/1289577024.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(df.iloc[mid])
# /tmp/ipykernel_18184/1289577024.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   points = points.append(binary_search(z_sort, z))
# /tmp/ipykernel_18184/1289577024.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   points = points.append(binary_search(x_sort, x))
# /tmp/ipykernel_18184/1289577024.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(df.iloc[mid])
# /tmp/ipykernel_18184/1289577024.py:36: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   points = points.append(binary_search(y_sort, y))
# /tmp/ipykernel_18184/1289577024.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(df.iloc[mid])
# /tmp/ipykernel_18184/1289577024.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(df.iloc[mid])
# /tmp/ipykernel_18184/1289577024.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(df.iloc[mid])
# /tmp/ipykernel_18184/1289577024.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(df.iloc[mid])
# /tmp/ipykernel_18184/1289577024.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   points = points.append(binary_search(z_sort, z))
# /tmp/ipykernel_18184/1289577024.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   points = points.append(binary_search(x_sort, x))
# /tmp/ipykernel_18184/1289577024.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(df.iloc[mid])
# /tmp/ipykernel_18184/1289577024.py:36: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   points = points.append(binary_search(y_sort, y))
# /tmp/ipykernel_18184/1289577024.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(df.iloc[mid])
# /tmp/ipykernel_18184/1289577024.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(df.iloc[mid])
# /tmp/ipykernel_18184/1289577024.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(df.iloc[mid])
# /tmp/ipykernel_18184/1289577024.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   points = points.append(binary_search(z_sort, z))
# /tmp/ipykernel_18184/1289577024.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   points = points.append(binary_search(x_sort, x))
# /tmp/ipykernel_18184/1289577024.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(df.iloc[mid])
# /tmp/ipykernel_18184/1289577024.py:36: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   points = points.append(binary_search(y_sort, y))
# /tmp/ipykernel_18184/1289577024.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(df.iloc[mid])
# /tmp/ipykernel_18184/1289577024.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   points = points.append(binary_search(z_sort, z))

# %%
ee
